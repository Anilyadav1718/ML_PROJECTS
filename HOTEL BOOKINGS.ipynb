# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\ANIL YADAV\\Downloads\\hotel_bookings.csv")
df
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0      Resort Hotel            0               2015               July
# 1      Resort Hotel            0               2015               July
# 2      Resort Hotel            0               2015               July
# 3      Resort Hotel            0               2015               July
# 4      Resort Hotel            0               2015               July
# ...             ...          ...                ...                ...
# 40055    City Hotel            0               2015             August
# 40056    City Hotel            0               2015             August
# 40057    City Hotel            0               2015             August
# 40058    City Hotel            0               2015             August
# 40059    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
a=df.groupby(['arrival_date_year','is_canceled'])['is_canceled'].count()
a
# Out:
# arrival_date_year  is_canceled
# 2015               0               6231
#                    1               2144
# 2016               0              13637
#                    1               4930
# 2017               0               9064
#                    1               4054
# Name: is_canceled, dtype: int64

# %%
ax=df.groupby(['market_segment','reserved_room_type'])['reserved_room_type'].count()
ax
# Out:
# market_segment  reserved_room_type
# Complementary   A                      120
#                 C                        5
#                 D                       17
#                 E                       22
#                 F                       27
#                 G                        8
#                 H                        2
# Corporate       A                     2107
#                 C                        8
#                 D                       94
#                 E                       90
#                 F                        2
#                 G                        6
#                 H                        2
# Direct          A                     2895
#                 B                        3
#                 C                      328
#                 D                     1119
#                 E                      959
#                 F                      699
#                 G                      349
# ...

# %%
ab=df.groupby(['arrival_date_year','arrival_date_month','is_canceled'])['is_canceled'].count()
ab
# Out:
# arrival_date_year  arrival_date_month  is_canceled
# 2015               August              0              1098
#                                        1               372
#                    December            0               961
#                                        1               305
#                    July                0              1058
#                                        1               320
#                    November            0               920
#                                        1               185
#                    October             0              1160
#                                        1               411
#                    September           0              1034
#                                        1               551
# 2016               April               0              1345
#                                        1               522
#                    August              0              1107
# ...

# %%
df.arrival_date_day_of_month.value_counts()
# Out:
# 12    1577
# 30    1463
# 5     1460
# 9     1430
# 16    1426
# 17    1394
# 26    1393
# 2     1388
# 18    1378
# 24    1367
# 25    1335
# 3     1325
# 15    1322
# 19    1305
# 4     1302
# 1     1294
# 8     1278
# 11    1272
# 28    1272
# 22    1270
# 27    1262
# 14    1219
# 7     1206
# 29    1203
# 21    1200
# 20    1197
# 6     1192
# 10    1187
# 23    1169
# 13    1140
# 31     834
# Name: arrival_date_day_of_month, dtype: int64

# %%
df.nunique()
# Out:
# hotel                          2
# is_canceled                    2
# arrival_date_year              3
# arrival_date_month            12
# arrival_date_day_of_month     31
# stays_in_weekend_nights       16
# stays_in_week_nights          31
# adults                        14
# children                       5
# country                      125
# market_segment                 6
# is_repeated_guest              2
# reserved_room_type            10
# assigned_room_type            11
# deposit_type                   3
# agent                        186
# company                      235
# customer_type                  4
# reservation_status             3
# reservation_status_date      908
# dtype: int64

# %%
df.country.value_counts(normalize=True)
# Out:
# PRT    0.445550
# GBR    0.171356
# ESP    0.100540
# IRL    0.054500
# FRA    0.040812
#          ...
# BIH    0.000025
# MUS    0.000025
# COM    0.000025
# UGA    0.000025
# DJI    0.000025
# Name: country, Length: 125, dtype: float64

# %%
sns.countplot(data=df, x='reserved_room_type',hue='market_segment')
plt.show()

# %%
sns.countplot(data=df, x='reserved_room_type')
plt.show()

# %%
sns.countplot(data=df, x='reserved_room_type',hue='is_repeated_guest')
plt.show()

# %%
sns.countplot(data=df, x='market_segment',hue='is_canceled')
plt.xticks(rotation=90)
plt.xticks(fontsize=13)
plt.title('BOOKINGS REGARDING MARKET SEGMENT')
# Out:
# Text(0.5, 1.0, 'BOOKINGS REGARDING MARKET SEGMENT')

# %%
sns.countplot(data=df, x='arrival_date_year',hue='is_canceled')
plt.xticks(rotation=90)
plt.xticks(fontsize=13)
plt.title('BOOKINGS IN EACH YEAR')
# Out:
# Text(0.5, 1.0, 'BOOKINGS IN EACH YEAR')

# %%
sns.countplot(data=df, x='customer_type',hue='is_canceled')
plt.xticks(rotation=90)
plt.xticks(fontsize=13)
plt.title('BOOKINGS IN CUSTOMER TYPE')
# Out:
# Text(0.5, 1.0, 'BOOKINGS IN CUSTOMER TYPE')

# %%
sns.countplot(data=df, x='hotel',hue='is_canceled')
plt.xticks(rotation=90)
plt.xticks(fontsize=13)
plt.title('BOOKINGS REGARDING HOTELS')
# Out:
# Text(0.5, 1.0, 'BOOKINGS REGARDING HOTELS')

# %%
sns.countplot(data=df, x='arrival_date_month',hue='is_canceled')
plt.xticks(rotation=90)
plt.xticks(fontsize=13)
plt.title('BOOKINGS IN EACH MONTH')
# Out:
# Text(0.5, 1.0, 'BOOKINGS IN EACH MONTH')

# %%
order=df['customer_type'].value_counts().index
plt.show()

# %%
# 1.Which type of hotel is mostly preferred by the people ?
2.What is the correlation b\w month and cancelled ?
3.Which day of month has the highest bookings(not cancelled)?
4.Which many repeated guests are there in 2015 ?
5.How adults choosen their reserved room type ?
6.Plot a countplot for market segment?
7.Filter out only the not cancelled booking?
# Out:
#   File "C:\Users\ANIL YADAV\AppData\Local\Temp\ipykernel_656\3708786657.py", line 2
#     2.What is the correlation b\w month and cancelled ?
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# abc=df.groupby(['arrival_date_year','arrival_date_month','is_canceled'])['is_canceled'].count()
# ab

# %%
abc=df.groupby(['is_canceled','arrival_date_year','arrival_date_month','is_repeated_guest'])['is_repeated_guest'].count()
abc

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_656\1685013873.py in <module>
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
bookings_2017=df[df.arrival_date_year==2017]
bookings_2017

# %%
df.to_csv('output.csv')

# %%
hotel_wise_bookings1=df.groupby(['hotel','arrival_date_year','is_canceled'])['hotel'].count()
hotel_wise_bookings1
# Out:
# hotel         arrival_date_year  is_canceled
# City Hotel    2015               0                 55
#                                  1                  6
# Resort Hotel  2015               0               6176
#                                  1               2138
#               2016               0              13637
#                                  1               4930
#               2017               0               9064
#                                  1               4054
# Name: hotel, dtype: int64

# %%
hotel_wise_bookings1=df.groupby(['hotel','arrival_date_year','is_canceled'])['hotel'].count()
hotel_wise_bookings1
# Out:
# hotel         arrival_date_year  is_canceled
# City Hotel    2015               0                 55
#                                  1                  6
# Resort Hotel  2015               0               6176
#                                  1               2138
#               2016               0              13637
#                                  1               4930
#               2017               0               9064
#                                  1               4054
# Name: hotel, dtype: int64

# %%
df
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0      Resort Hotel            0               2015               July
# 1      Resort Hotel            0               2015               July
# 2      Resort Hotel            0               2015               July
# 3      Resort Hotel            0               2015               July
# 4      Resort Hotel            0               2015               July
# ...             ...          ...                ...                ...
# 40055    City Hotel            0               2015             August
# 40056    City Hotel            0               2015             August
# 40057    City Hotel            0               2015             August
# 40058    City Hotel            0               2015             August
# 40059    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
data2=df.groupby(['adults','assigned_room_type'])['assigned_room_type'].count()
data2
# Out:
# adults  assigned_room_type
# 0       A                         3
#         B                         1
#         C                         2
#         D                         1
#         G                         1
#         I                         4
#         P                         2
# 1       A                      3834
#         B                        37
#         C                       229
#         D                      2040
#         E                       629
#         F                       171
#         G                        99
#         H                        35
#         I                        77
# 2       A                     12906
#         B                       120
#         C                      1759
#         D                      8067
#         E                      4883
#         F                      1503
#         G                      1653
#         H                       259
#         I                       269
# ...

# %%
df.hotel.value_counts()
# Out:
# Resort Hotel    39999
# City Hotel         61
# Name: hotel, dtype: int64

# %%
df['arrival_date_day_of_month'].mode()[0]
# Out:
# 12

# %%
df['assigned_room_type'].mode()[0]
# Out:
# 'A'

# %%
df.assigned_room_type.value_counts().barplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26092\2737866459.py in <module>
# ----> 1 df.assigned_room_type.value_counts().barplot()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'barplot'

# %%
sns.countplot(data=df, x='is_canceled',hue='hotel')
plt.show()

# %%
df2=df.loc[df['is_canceled']==0]
df2
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0      Resort Hotel            0               2015               July
# 1      Resort Hotel            0               2015               July
# 2      Resort Hotel            0               2015               July
# 3      Resort Hotel            0               2015               July
# 4      Resort Hotel            0               2015               July
# ...             ...          ...                ...                ...
# 40055    City Hotel            0               2015             August
# 40056    City Hotel            0               2015             August
# 40057    City Hotel            0               2015             August
# 40058    City Hotel            0               2015             August
# 40059    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
df.filter('is_canceled'==0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26092\3903329701.py in <module>
# ----> 1 df.filter('is_canceled'==0)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    5129         if items is not None:
#    5130             name = self._get_axis_name(axis)
# -> 5131             return self.reindex(**{name: [r for r in items if r in labels]})
#    5132         elif like:
#    5133
#
# TypeError: 'bool' object is not iterable

# %%
df3=df.loc[df['is_canceled']==1]
df3
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 8      Resort Hotel            1               2015               July
# 9      Resort Hotel            1               2015               July
# 10     Resort Hotel            1               2015               July
# 27     Resort Hotel            1               2015               July
# 32     Resort Hotel            1               2015               July
# ...             ...          ...                ...                ...
# 40007    City Hotel            1               2015             August
# 40022    City Hotel            1               2015             August
# 40027    City Hotel            1               2015             August
# 40034    City Hotel            1               2015             August
# 40051    City Hotel            1               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
df.is_canceled.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df2.is_canceled.unique()
# Out:
# array([0], dtype=int64)

# %%
df['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.722217
# 1    0.277783
# Name: is_canceled, dtype: float64

# %%
df.rating.sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18088\2551215474.py in <module>
# ----> 1 df.rating.sort_values()
#
# NameError: name 'df' is not defined

# %%
sns.countplot(x='is_canceled',hue='hotel',data=df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
sns.lineplot(x='arrival_date_year',y='is_canceled',hue='hotel',data=df)
plt.xticks(rotation=90)
# Out:
# (array([2014.75, 2015.  , 2015.25, 2015.5 , 2015.75, 2016.  , 2016.25,
#         2016.5 , 2016.75, 2017.  , 2017.25]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.countplot(x='hotel',hue='is_canceled',data=df)
# Out:
# <AxesSubplot:xlabel='hotel', ylabel='count'>
